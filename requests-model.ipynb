# %% [markdown]
# # Tutoriel d'usage de l'API

# %%
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

# %% [markdown]
# ## Creating an avatar

# %% [markdown]
# The admin of the competition can create users. A user can then create as many avatars as they wish.

# %%
import requests

user_id = '88be3640-82ae-46c6-ac59-92a9679d453d'
name = 'laulau'
r = requests.post(path(f'avatars/{user_id}/{name}'))
r
# Out:
# <Response [200]>

# %%
name = 'Nini'
r = requests.post(path(f"avatars/{user_id}/{name}"))
r
# Out:
# <Response [200]>

# %%
name = 'Tess'
r = requests.post(path(f"avatars/{user_id}/{name}"))
r
# Out:
# <Response [200]>

# %%
r = requests.get(path(f"avatars/{user_id}"))
for avatar in r.json():
    print(avatar['id'], avatar['name'])
# Out:
# 3533 laulau
# 3534 Nini
# 3535 Tess

# %% [markdown]
# ## Making pricing requests

# %%
params = {
    "avatar_name": "laulau",
    "language": "french",
    "city": "copenhagen",
    "date": 30,
    "mobile": 0,
}
r1 = requests.get(path(f"pricing/{user_id}"), params=params)
r1.json()
# Out:
# {'prices': [{'hotel_id': 519, 'price': 208, 'stock': 68},
#   {'hotel_id': 523, 'price': 85, 'stock': 41},
#   {'hotel_id': 898, 'price': 86, 'stock': 24},
#   {'hotel_id': 770, 'price': 210, 'stock': 73},
#   {'hotel_id': 562, 'price': 215, 'stock': 74},
#   {'hotel_id': 669, 'price': 203, 'stock': 76},
#   {'hotel_id': 876, 'price': 131, 'stock': 36},
#   {'hotel_id': 53, 'price': 96, 'stock': 24},
#   {'hotel_id': 744, 'price': 173, 'stock': 55},
#   {'hotel_id': 831, 'price': 92, 'stock': 19},
#   {'hotel_id': 900, 'price': 192, 'stock': 80},
#   {'hotel_id': 772, 'price': 304, 'stock': 85},
#   {'hotel_id': 518, 'price': 117, 'stock': 43},
#   {'hotel_id': 100, 'price': 91, 'stock': 21},
#   {'hotel_id': 961, 'price': 187, 'stock': 85},
#   {'hotel_id': 113, 'price': 89, 'stock': 28},
#   {'hotel_id': 983, 'price': 88, 'stock': 27},
#   {'hotel_id': 556, 'price': 182, 'stock': 60},
#   {'hotel_id': 243, 'price': 97, 'stock': 21},
#   {'hotel_id': 757, 'price': 134, 'stock': 37},
#   {'hotel_id': 990, 'price': 164, 'stock': 58},
#   {'hotel_id': 401, 'price': 182, 'stock': 48},
#   {'hotel_id': 350, 'price': 308, 'stock': 125},
#   {'hotel_id': 249, 'price': 87, 'stock': 68},
#   {'hotel_id': 930, 'price': 117, 'stock': 70},
#   {'hotel_id': 541, 'price': 129, 'stock': 43},
#   {'hotel_id': 96, 'price': 129, 'stock': 37},
#   {'hotel_id': 691, 'price': 85, 'stock': 51},
#   {'hotel_id': 981, 'price': 98, 'stock': 22},
#   {'hotel_id': 793, 'price': 167, 'stock': 23},
#   {'hotel_id': 407, 'price': 216, 'stock': 69},
#   {'hotel_id': 329, 'price': 231, 'stock': 67},
#   {'hotel_id': 425, 'price': 190, 'stock': 92},
#   {'hotel_id': 958, 'price': 223, 'stock': 72},
#   {'hotel_id': 289, 'price': 125, 'stock': 40},
#   {'hotel_id': 528, 'price': 280, 'stock': 99},
#   {'hotel_id': 664, 'price': 295, 'stock': 111},
#   {'hotel_id': 688, 'price': 87, 'stock': 45},
#   {'hotel_id': 435, 'price': 302, 'stock': 97},
#   {'hotel_id': 431, 'price': 128, 'stock': 38},
#   {'hotel_id': 50, 'price': 133, 'stock': 39},
#   {'hotel_id': 349, 'price': 226, 'stock': 68},
#   {'hotel_id': 616, 'price': 177, 'stock': 50},
#   {'hotel_id': 124, 'price': 277, 'stock': 120},
#   {'hotel_id': 622, 'price': 127, 'stock': 50},
#   {'hotel_id': 506, 'price': 126, 'stock': 23},
#   {'hotel_id': 546, 'price': 88, 'stock': 47},
#   {'hotel_id': 194, 'price': 123, 'stock': 20},
#   {'hotel_id': 855, 'price': 192, 'stock': 85},
#   {'hotel_id': 92, 'price': 88, 'stock': 27},
#   {'hotel_id': 865, 'price': 288, 'stock': 107},
#   {'hotel_id': 690, 'price': 206, 'stock': 82},
#   {'hotel_id': 829, 'price': 187, 'stock': 56},
#   {'hotel_id': 481, 'price': 97, 'stock': 21},
#   {'hotel_id': 402, 'price': 134, 'stock': 38},
#   {'hotel_id': 514, 'price': 266, 'stock': 129},
#   {'hotel_id': 869, 'price': 293, 'stock': 98},
#   {'hotel_id': 572, 'price': 206, 'stock': 64},
#   {'hotel_id': 726, 'price': 278, 'stock': 103},
#   {'hotel_id': 959, 'price': 196, 'stock': 74},
#   {'hotel_id': 611, 'price': 182, 'stock': 56},
#   {'hotel_id': 894, 'price': 301, 'stock': 105},
#   {'hotel_id': 539, 'price': 277, 'stock': 117},
#   {'hotel_id': 433, 'price': 117, 'stock': 45},
#   {'hotel_id': 812, 'price': 185, 'stock': 48},
#   {'hotel_id': 300, 'price': 124, 'stock': 38},
#   {'hotel_id': 547, 'price': 180, 'stock': 50},
#   {'hotel_id': 716, 'price': 133, 'stock': 40},
#   {'hotel_id': 994, 'price': 163, 'stock': 62},
#   {'hotel_id': 463, 'price': 101, 'stock': 18},
#   {'hotel_id': 6, 'price': 120, 'stock': 49},
#   {'hotel_id': 358, 'price': 198, 'stock': 73},
#   {'hotel_id': 391, 'price': 177, 'stock': 54},
#   {'hotel_id': 99, 'price': 187, 'stock': 46},
#   {'hotel_id': 91, 'price': 129, 'stock': 20},
#   {'hotel_id': 487, 'price': 173, 'stock': 62},
#   {'hotel_id': 422, 'price': 301, 'stock': 102},
#   {'hotel_id': 655, 'price': 280, 'stock': 111},
#   {'hotel_id': 908, 'price': 326, 'stock': 92},
#   {'hotel_id': 638, 'price': 159, 'stock': 63},
#   {'hotel_id': 952, 'price': 96, 'stock': 22},
#   {'hotel_id': 434, 'price': 106, 'stock': 18},
#   {'hotel_id': 893, 'price': 213, 'stock': 69},
#   {'hotel_id': 624, 'price': 208, 'stock': 75},
#   {'hotel_id': 532, 'price': 213, 'stock': 76},
#   {'hotel_id': 443, 'price': 119, 'stock': 52},
#   {'hotel_id': 78, 'price': 277, 'stock': 93},
#   {'hotel_id': 830, 'price': 91, 'stock': 51},
#   {'hotel_id': 43, 'price': 83, 'stock': 62},
#   {'hotel_id': 727, 'price': 126, 'stock': 19},
#   {'hotel_id': 365, 'price': 96, 'stock': 23},
#   {'hotel_id': 405, 'price': 101, 'stock': 22},
#   {'hotel_id': 761, 'price': 124, 'stock': 47},
#   {'hotel_id': 60, 'price': 94, 'stock': 23},
#   {'hotel_id': 36, 'price': 201, 'stock': 44},
#   {'hotel_id': 995, 'price': 196, 'stock': 72},
#   {'hotel_id': 826, 'price': 204, 'stock': 83},
#   {'hotel_id': 938, 'price': 124, 'stock': 26},
#   {'hotel_id': 844, 'price': 281, 'stock': 108},
#   {'hotel_id': 90, 'price': 171, 'stock': 56},
#   {'hotel_id': 707, 'price': 299, 'stock': 103},
#   {'hotel_id': 202, 'price': 162, 'stock': 52},
#   {'hotel_id': 251, 'price': 171, 'stock': 21},
#   {'hotel_id': 291, 'price': 196, 'stock': 79},
#   {'hotel_id': 267, 'price': 180, 'stock': 58},
#   {'hotel_id': 720, 'price': 280, 'stock': 118},
#   {'hotel_id': 309, 'price': 98, 'stock': 44},
#   {'hotel_id': 58, 'price': 211, 'stock': 65},
#   {'hotel_id': 559, 'price': 204, 'stock': 74},
#   {'hotel_id': 110, 'price': 173, 'stock': 51},
#   {'hotel_id': 445, 'price': 93, 'stock': 22},
#   {'hotel_id': 531, 'price': 182, 'stock': 53},
#   {'hotel_id': 23, 'price': 170, 'stock': 56},
#   {'hotel_id': 695, 'price': 180, 'stock': 50},
#   {'hotel_id': 280, 'price': 122, 'stock': 64},
#   {'hotel_id': 508, 'price': 203, 'stock': 78},
#   {'hotel_id': 318, 'price': 141, 'stock': 36},
#   {'hotel_id': 1, 'price': 99, 'stock': 39},
#   {'hotel_id': 973, 'price': 178, 'stock': 54},
#   {'hotel_id': 497, 'price': 210, 'stock': 71},
#   {'hotel_id': 805, 'price': 165, 'stock': 74},
#   {'hotel_id': 818, 'price': 180, 'stock': 44},
#   {'hotel_id': 834, 'price': 95, 'stock': 16},
#   {'hotel_id': 153, 'price': 216, 'stock': 66},
#   {'hotel_id': 711, 'price': 135, 'stock': 38},
#   {'hotel_id': 872, 'price': 97, 'stock': 27},
#   {'hotel_id': 319, 'price': 298, 'stock': 116},
#   {'hotel_id': 849, 'price': 162, 'stock': 52},
#   {'hotel_id': 32, 'price': 182, 'stock': 57},
#   {'hotel_id': 142, 'price': 316, 'stock': 115},
#   {'hotel_id': 922, 'price': 231, 'stock': 63},
#   {'hotel_id': 766, 'price': 304, 'stock': 102},
#   {'hotel_id': 989, 'price': 93, 'stock': 22},
#   {'hotel_id': 122, 'price': 290, 'stock': 120},
#   {'hotel_id': 596, 'price': 177, 'stock': 40},
#   {'hotel_id': 698, 'price': 198, 'stock': 74},
#   {'hotel_id': 951, 'price': 87, 'stock': 47},
#   {'hotel_id': 348, 'price': 162, 'stock': 76},
#   {'hotel_id': 771, 'price': 299, 'stock': 109},
#   {'hotel_id': 332, 'price': 208, 'stock': 86},
#   {'hotel_id': 978, 'price': 299, 'stock': 120},
#   {'hotel_id': 335, 'price': 91, 'stock': 46},
#   {'hotel_id': 385, 'price': 283, 'stock': 101},
#   {'hotel_id': 367, 'price': 96, 'stock': 24}],
#  'request': {'city': 'copenhagen',
#   'date': 30,
#   'language': 'french',
#   'mobile': 0,
#   'avatar_id': 3533}}

# %%
import requests 

params = {
    "avatar_name": "Nini",
    "language": "swedish",
    "city": "paris",
    "date": 35,
    "mobile": 1,
}

r2 = requests.get(path(f"pricing/{user_id}"), params=params)
r2.json()
# Out:
# {'prices': [{'hotel_id': 254, 'price': 170, 'stock': 82},
#   {'hotel_id': 980, 'price': 118, 'stock': 64},
#   {'hotel_id': 614, 'price': 93, 'stock': 32},
#   {'hotel_id': 148, 'price': 123, 'stock': 60},
#   {'hotel_id': 656, 'price': 115, 'stock': 64},
#   {'hotel_id': 790, 'price': 282, 'stock': 151},
#   {'hotel_id': 41, 'price': 120, 'stock': 60},
#   {'hotel_id': 56, 'price': 197, 'stock': 111},
#   {'hotel_id': 599, 'price': 111, 'stock': 74},
#   {'hotel_id': 731, 'price': 174, 'stock': 74},
#   {'hotel_id': 17, 'price': 88, 'stock': 35},
#   {'hotel_id': 797, 'price': 124, 'stock': 70},
#   {'hotel_id': 645, 'price': 170, 'stock': 78},
#   {'hotel_id': 617, 'price': 303, 'stock': 152},
#   {'hotel_id': 736, 'price': 200, 'stock': 110},
#   {'hotel_id': 663, 'price': 161, 'stock': 84},
#   {'hotel_id': 339, 'price': 205, 'stock': 108},
#   {'hotel_id': 756, 'price': 206, 'stock': 102},
#   {'hotel_id': 331, 'price': 91, 'stock': 60},
#   {'hotel_id': 986, 'price': 200, 'stock': 113},
#   {'hotel_id': 837, 'price': 261, 'stock': 161},
#   {'hotel_id': 415, 'price': 126, 'stock': 62},
#   {'hotel_id': 577, 'price': 174, 'stock': 75},
#   {'hotel_id': 564, 'price': 99, 'stock': 31},
#   {'hotel_id': 121, 'price': 84, 'stock': 37},
#   {'hotel_id': 817, 'price': 203, 'stock': 103},
#   {'hotel_id': 216, 'price': 200, 'stock': 108},
#   {'hotel_id': 808, 'price': 274, 'stock': 145},
#   {'hotel_id': 392, 'price': 175, 'stock': 81},
#   {'hotel_id': 803, 'price': 295, 'stock': 154},
#   {'hotel_id': 560, 'price': 165, 'stock': 78},
#   {'hotel_id': 571, 'price': 271, 'stock': 153},
#   {'hotel_id': 119, 'price': 188, 'stock': 117},
#   {'hotel_id': 842, 'price': 311, 'stock': 143},
#   {'hotel_id': 963, 'price': 120, 'stock': 66},
#   {'hotel_id': 522, 'price': 117, 'stock': 63},
#   {'hotel_id': 229, 'price': 188, 'stock': 110},
#   {'hotel_id': 257, 'price': 174, 'stock': 73},
#   {'hotel_id': 582, 'price': 203, 'stock': 111},
#   {'hotel_id': 308, 'price': 209, 'stock': 103},
#   {'hotel_id': 863, 'price': 271, 'stock': 173},
#   {'hotel_id': 115, 'price': 116, 'stock': 72},
#   {'hotel_id': 741, 'price': 183, 'stock': 76},
#   {'hotel_id': 998, 'price': 200, 'stock': 115},
#   {'hotel_id': 24, 'price': 264, 'stock': 188},
#   {'hotel_id': 323, 'price': 291, 'stock': 155},
#   {'hotel_id': 49, 'price': 170, 'stock': 88},
#   {'hotel_id': 314, 'price': 124, 'stock': 62},
#   {'hotel_id': 338, 'price': 203, 'stock': 102},
#   {'hotel_id': 359, 'price': 126, 'stock': 59},
#   {'hotel_id': 176, 'price': 93, 'stock': 25},
#   {'hotel_id': 576, 'price': 201, 'stock': 102},
#   {'hotel_id': 942, 'price': 194, 'stock': 102},
#   {'hotel_id': 299, 'price': 117, 'stock': 76},
#   {'hotel_id': 62, 'price': 83, 'stock': 34},
#   {'hotel_id': 868, 'price': 184, 'stock': 114},
#   {'hotel_id': 723, 'price': 83, 'stock': 33},
#   {'hotel_id': 199, 'price': 212, 'stock': 104},
#   {'hotel_id': 207, 'price': 178, 'stock': 81},
#   {'hotel_id': 767, 'price': 174, 'stock': 74},
#   {'hotel_id': 705, 'price': 132, 'stock': 60},
#   {'hotel_id': 926, 'price': 186, 'stock': 113},
#   {'hotel_id': 825, 'price': 174, 'stock': 80},
#   {'hotel_id': 225, 'price': 170, 'stock': 74},
#   {'hotel_id': 629, 'price': 94, 'stock': 65},
#   {'hotel_id': 248, 'price': 186, 'stock': 108},
#   {'hotel_id': 634, 'price': 89, 'stock': 33},
#   {'hotel_id': 29, 'price': 197, 'stock': 109},
#   {'hotel_id': 734, 'price': 126, 'stock': 61},
#   {'hotel_id': 640, 'price': 164, 'stock': 70},
#   {'hotel_id': 580, 'price': 126, 'stock': 56},
#   {'hotel_id': 274, 'price': 162, 'stock': 76},
#   {'hotel_id': 14, 'price': 162, 'stock': 68},
#   {'hotel_id': 795, 'price': 179, 'stock': 78},
#   {'hotel_id': 132, 'price': 267, 'stock': 155},
#   {'hotel_id': 290, 'price': 178, 'stock': 73},
#   {'hotel_id': 306, 'price': 203, 'stock': 105},
#   {'hotel_id': 631, 'price': 87, 'stock': 32},
#   {'hotel_id': 949, 'price': 292, 'stock': 151},
#   {'hotel_id': 477, 'price': 85, 'stock': 84},
#   {'hotel_id': 841, 'price': 84, 'stock': 70},
#   {'hotel_id': 776, 'price': 172, 'stock': 77},
#   {'hotel_id': 708, 'price': 167, 'stock': 74},
#   {'hotel_id': 584, 'price': 275, 'stock': 165},
#   {'hotel_id': 159, 'price': 188, 'stock': 116},
#   {'hotel_id': 722, 'price': 164, 'stock': 74},
#   {'hotel_id': 492, 'price': 119, 'stock': 68},
#   {'hotel_id': 885, 'price': 184, 'stock': 74},
#   {'hotel_id': 782, 'price': 287, 'stock': 169},
#   {'hotel_id': 133, 'price': 171, 'stock': 76},
#   {'hotel_id': 910, 'price': 90, 'stock': 35},
#   {'hotel_id': 972, 'price': 85, 'stock': 31},
#   {'hotel_id': 602, 'price': 115, 'stock': 37},
#   {'hotel_id': 95, 'price': 270, 'stock': 174},
#   {'hotel_id': 227, 'price': 87, 'stock': 32},
#   {'hotel_id': 342, 'price': 122, 'stock': 35},
#   {'hotel_id': 540, 'price': 284, 'stock': 158},
#   {'hotel_id': 66, 'price': 150, 'stock': 88},
#   {'hotel_id': 467, 'price': 276, 'stock': 153},
#   {'hotel_id': 912, 'price': 178, 'stock': 73},
#   {'hotel_id': 970, 'price': 272, 'stock': 171},
#   {'hotel_id': 188, 'price': 92, 'stock': 36},
#   {'hotel_id': 858, 'price': 188, 'stock': 110},
#   {'hotel_id': 853, 'price': 159, 'stock': 78},
#   {'hotel_id': 65, 'price': 163, 'stock': 84},
#   {'hotel_id': 573, 'price': 322, 'stock': 149},
#   {'hotel_id': 975, 'price': 172, 'stock': 72},
#   {'hotel_id': 182, 'price': 164, 'stock': 90},
#   {'hotel_id': 700, 'price': 192, 'stock': 136},
#   {'hotel_id': 851, 'price': 89, 'stock': 69},
#   {'hotel_id': 379, 'price': 282, 'stock': 162},
#   {'hotel_id': 259, 'price': 122, 'stock': 53},
#   {'hotel_id': 397, 'price': 287, 'stock': 156},
#   {'hotel_id': 684, 'price': 87, 'stock': 32},
#   {'hotel_id': 28, 'price': 135, 'stock': 60},
#   {'hotel_id': 150, 'price': 201, 'stock': 105},
#   {'hotel_id': 946, 'price': 201, 'stock': 104},
#   {'hotel_id': 222, 'price': 270, 'stock': 150},
#   {'hotel_id': 357, 'price': 167, 'stock': 74},
#   {'hotel_id': 412, 'price': 287, 'stock': 176},
#   {'hotel_id': 69, 'price': 272, 'stock': 194},
#   {'hotel_id': 785, 'price': 192, 'stock': 102},
#   {'hotel_id': 130, 'price': 196, 'stock': 104},
#   {'hotel_id': 162, 'price': 291, 'stock': 150},
#   {'hotel_id': 866, 'price': 271, 'stock': 171},
#   {'hotel_id': 192, 'price': 123, 'stock': 33},
#   {'hotel_id': 884, 'price': 190, 'stock': 111},
#   {'hotel_id': 738, 'price': 121, 'stock': 66},
#   {'hotel_id': 123, 'price': 120, 'stock': 60},
#   {'hotel_id': 27, 'price': 271, 'stock': 169},
#   {'hotel_id': 558, 'price': 90, 'stock': 31},
#   {'hotel_id': 742, 'price': 268, 'stock': 149},
#   {'hotel_id': 792, 'price': 89, 'stock': 76},
#   {'hotel_id': 327, 'price': 210, 'stock': 102},
#   {'hotel_id': 937, 'price': 191, 'stock': 104},
#   {'hotel_id': 419, 'price': 115, 'stock': 67},
#   {'hotel_id': 889, 'price': 162, 'stock': 78},
#   {'hotel_id': 748, 'price': 190, 'stock': 129},
#   {'hotel_id': 21, 'price': 85, 'stock': 36},
#   {'hotel_id': 447, 'price': 115, 'stock': 66},
#   {'hotel_id': 595, 'price': 159, 'stock': 84},
#   {'hotel_id': 0, 'price': 186, 'stock': 106},
#   {'hotel_id': 436, 'price': 267, 'stock': 187},
#   {'hotel_id': 94, 'price': 270, 'stock': 193},
#   {'hotel_id': 534, 'price': 271, 'stock': 160},
#   {'hotel_id': 823, 'price': 194, 'stock': 106},
#   {'hotel_id': 165, 'price': 163, 'stock': 86},
#   {'hotel_id': 911, 'price': 121, 'stock': 75},
#   {'hotel_id': 612, 'price': 192, 'stock': 111},
#   {'hotel_id': 421, 'price': 124, 'stock': 64},
#   {'hotel_id': 579, 'price': 86, 'stock': 35},
#   {'hotel_id': 948, 'price': 200, 'stock': 113},
#   {'hotel_id': 903, 'price': 92, 'stock': 72},
#   {'hotel_id': 526, 'price': 287, 'stock': 155},
#   {'hotel_id': 882, 'price': 196, 'stock': 110},
#   {'hotel_id': 735, 'price': 120, 'stock': 59}],
#  'request': {'city': 'paris',
#   'date': 35,
#   'language': 'swedish',
#   'mobile': 1,
#   'avatar_id': 3534}}

# %%
params = {
    "avatar_name": "max-second-avatar",
    "language": "hungarian",
    "city": "amsterdam",
    "date": 1,
    "mobile": 1,
}
r2 = requests.get(path(f"pricing/{user_id}"), params=params)
r2.json()

# %% [markdown]
# ## Build a training set

# %%
import pandas as pd

pricing_requests = []

request = [r2]
for r in request:
    pricing_requests.append(
        pd.DataFrame(r.json()['prices']).assign(**r.json()['request'])
    )

pricing_requests = pd.concat(pricing_requests)
pricing_requests.head()
# Out:
#    hotel_id  price  stock   city  date language  mobile  avatar_id
# 0       254    170     82  paris    35  swedish       1       3534
# 1       980    118     64  paris    35  swedish       1       3534
# 2       614     93     32  paris    35  swedish       1       3534
# 3       148    123     60  paris    35  swedish       1       3534
# 4       656    115     64  paris    35  swedish       1       3534

# %%
len(pricing_requests)
# Out:
# 144

# %%
#on enregistre la requête
pricing_requests.to_csv("Nini_paris_35_1.csv")

# %%
hotels = pd.read_csv('../input/defi-ia-2023/features_hotels.csv', index_col=['hotel_id', 'city'])
pricing_requests = pricing_requests.join(hotels, on=['hotel_id', 'city'])
pricing_requests.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_17/2771263561.py in <module>
# ----> 1 hotels = pd.read_csv('../input/defi-ia-2023/features_hotels.csv', index_col=['hotel_id', 'city'])
#       2 pricing_requests = pricing_requests.join(hotels, on=['hotel_id', 'city'])
#       3 pricing_requests.head()
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/defi-ia-2023/features_hotels.csv'

# %%
#sample_submission = pd.read_csv('../input/defi-ia-2023/sample_submission.csv')
#sample_submission.head()

# %%
#sample_submission.to_csv('submission.csv', index=False)
