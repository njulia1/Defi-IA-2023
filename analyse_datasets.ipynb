# %% [markdown]
# # Analyse des datasets d'entraînement et de test
# Ce notebook contient les informations sur le dataset obtenu via les requêtes, sur lequel on construit nos modèles (échantillon de test et d'apprentissage), ainsi que les informations concernant la répartition des données sur le jeu de données de tests.

# %%
# !pip install pyensae
# Out:
# Requirement already satisfied: pyensae in d:\logiciels\anaconda\installation\lib\site-packages (1.3.884)
# Requirement already satisfied: pandas>=1.0 in d:\logiciels\anaconda\installation\lib\site-packages (from pyensae) (1.1.3)
# Requirement already satisfied: matplotlib>=3.0 in d:\logiciels\anaconda\installation\lib\site-packages (from pyensae) (3.6.2)
# Requirement already satisfied: pyquickhelper>=1.8 in d:\logiciels\anaconda\installation\lib\site-packages (from pyensae) (1.11.3697)
# Requirement already satisfied: numpy>=1.18 in d:\logiciels\anaconda\installation\lib\site-packages (from pyensae) (1.23.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (8.0.1)
# Requirement already satisfied: cycler>=0.10 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (0.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\logiciels\anaconda\installation\lib\site-packages (from matplotlib>=3.0->pyensae) (1.0.6)
# Requirement already satisfied: pytz>=2017.2 in d:\logiciels\anaconda\installation\lib\site-packages (from pandas>=1.0->pyensae) (2020.1)
# Requirement already satisfied: pyquicksetup>=0.2 in d:\logiciels\anaconda\installation\lib\site-packages (from pyquickhelper>=1.8->pyensae) (0.2)
# Requirement already satisfied: fire in d:\logiciels\anaconda\installation\lib\site-packages (from pyquickhelper>=1.8->pyensae) (0.4.0)
# Requirement already satisfied: six in d:\logiciels\anaconda\installation\lib\site-packages (from cycler>=0.10->matplotlib>=3.0->pyensae) (1.15.0)
# Requirement already satisfied: setuptools in d:\logiciels\anaconda\installation\lib\site-packages (from pyquicksetup>=0.2->pyquickhelper>=1.8->pyensae) (50.3.1.post20201107)
# Requirement already satisfied: termcolor in d:\logiciels\anaconda\installation\lib\site-packages (from fire->pyquickhelper>=1.8->pyensae) (1.1.0)
# WARNING: Ignoring invalid distribution -pencv-python (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\logiciels\anaconda\installation\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\logiciels\anaconda\installation\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pyensae

# %matplotlib inline

# %% [markdown]
# ## Etude de l'échantillon de test (non variable)
# ### Analyse descriptive des variables

# %%
df_test = pd.read_csv('test_set.csv')
df_test.head()
# Out:
#    index  order_requests     city  date  language  mobile  avatar_id  \
# 0      0               1  vilnius    21  romanian       0          1
# 1      1               1  vilnius    21  romanian       0          1
# 2      2               1  vilnius    21  romanian       0          1
# 3      3               1  vilnius    21  romanian       0          1
# 4      4               1  vilnius    21  romanian       0          1
#
#    hotel_id  stock
# 0       161     46
# 1       187     32
# 2       279     12
# 3       395     10
# 4       488     42

# %%
cities = np.unique(df_test['city'])
for city in cities:
    print('Number of occurence of ', city,' in test set = ' "{:.2f}".format(len(df_test[df_test['city'] == city].index)/len(df_test.index)*100), "%")

percent_city_df_test = ["{:.2f}".format(len(df_test[df_test['city'] == city].index)/len(df_test.index)*100) for city in cities]

cit = np.array([len(df_test[df_test['city'] == i].index) for i in cities])
plt.pie(cit, labels = cities, startangle = 90)
plt.show()
# Out:
# Number of occurence of  amsterdam  in test set = 17.07 %
# Number of occurence of  copenhagen  in test set = 10.88 %
# Number of occurence of  madrid  in test set = 16.47 %
# Number of occurence of  paris  in test set = 16.93 %
# Number of occurence of  rome  in test set = 10.85 %
# Number of occurence of  sofia  in test set = 5.63 %
# Number of occurence of  valletta  in test set = 4.46 %
# Number of occurence of  vienna  in test set = 8.55 %
# Number of occurence of  vilnius  in test set = 9.17 %

# %%
languages = np.unique(df_test['language'])
for language in languages:
    print('Number of occurence of ', language,' in test set = ' "{:.2f}".format(len(df_test[df_test['language'] == language].index)/len(df_test.index)*100), "%")

percent_lan_df_test = ["{:.2f}".format(len(df_test[df_test['language'] == language].index)/len(df_test.index)*100) for language in languages]

lan = np.array([len(df_test[df_test['language'] == i].index) for i in languages])
plt.pie(lan, labels = languages, startangle = 90)
plt.show()
# Out:
# Number of occurence of  austrian  in test set = 6.94 %
# Number of occurence of  belgian  in test set = 2.30 %
# Number of occurence of  bulgarian  in test set = 5.36 %
# Number of occurence of  croatian  in test set = 1.52 %
# Number of occurence of  cypriot  in test set = 1.60 %
# Number of occurence of  czech  in test set = 1.57 %
# Number of occurence of  danish  in test set = 5.21 %
# Number of occurence of  dutch  in test set = 2.02 %
# Number of occurence of  estonian  in test set = 5.87 %
# Number of occurence of  finnish  in test set = 7.01 %
# Number of occurence of  french  in test set = 1.93 %
# Number of occurence of  german  in test set = 1.20 %
# Number of occurence of  greek  in test set = 2.72 %
# Number of occurence of  hungarian  in test set = 14.55 %
# Number of occurence of  irish  in test set = 3.15 %
# Number of occurence of  italian  in test set = 1.93 %
# Number of occurence of  latvian  in test set = 1.70 %
# Number of occurence of  lithuanian  in test set = 1.84 %
# Number of occurence of  luxembourgish  in test set = 1.88 %
# Number of occurence of  maltese  in test set = 2.97 %
# Number of occurence of  polish  in test set = 1.97 %
# Number of occurence of  portuguese  in test set = 1.05 %
# Number of occurence of  romanian  in test set = 6.61 %
# Number of occurence of  slovakian  in test set = 6.29 %
# Number of occurence of  slovene  in test set = 2.62 %
# Number of occurence of  spanish  in test set = 2.12 %
# Number of occurence of  swedish  in test set = 6.08 %

# %%
mobiles = np.unique(df_test['mobile'])
for mobile in mobiles:
    print('Number of occurence of ', mobile,' in test set = ', len(df_test[df_test['mobile'] == mobile].index))

mob = np.array([len(df_test[df_test['mobile'] == i].index) for i in mobiles])
plt.pie(mob, labels = mobiles, startangle = 90)
plt.show()
# Out:
# Number of occurence of  0  in test set =  3630
# Number of occurence of  1  in test set =  3014

# %%
sns.distplot(df_test['date'],kde=True).set(title="Date",xlabel=None)
plt.show()
# Out:
# d:\Logiciels\Anaconda\Installation\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Etude de l'échantillon de données

# %%
df = pd.read_csv('data3.csv')
df.head()
# Out:
#    hotel_id                   group          brand        city  parking  pool  \
# 0       519                Yin Yang    Royal Lotus  copenhagen        0     0
# 1       523             Independant    Independant  copenhagen        0     0
# 2       898                Yin Yang      8 Premium  copenhagen        1     0
# 3       770  Morriott International        Morriot  copenhagen        1     1
# 4       562      Chillton Worldwide  Quadrupletree  copenhagen        0     0
#
#    children_policy  price  stock  date language  mobile avatar_name  \
# 0                0    208     68    30   french       0      laulau
# 1                0     85     41    30   french       0      laulau
# 2                0     86     24    30   french       0      laulau
# 3                0    210     73    30   french       0      laulau
# 4                0    215     74    30   french       0      laulau
#
#    order_requests
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
cities = np.unique(df['city'])
for city in cities:
     print('Number of occurence of ', city,' in test set = ' "{:.2f}".format(len(df[df['city'] == city].index)/len(df.index)*100), "%")

percent_city_df = ["{:.2f}".format(len(df[df['city'] == city].index)/len(df.index)*100) for city in cities]
cit = np.array([len(df[df['city'] == i].index) for i in cities])
plt.pie(cit, labels = cities, startangle = 90)
plt.show()
# Out:
# Number of occurence of  amsterdam  in test set = 17.42 %
# Number of occurence of  copenhagen  in test set = 7.12 %
# Number of occurence of  madrid  in test set = 13.51 %
# Number of occurence of  paris  in test set = 19.63 %
# Number of occurence of  rome  in test set = 15.36 %
# Number of occurence of  sofia  in test set = 6.49 %
# Number of occurence of  valletta  in test set = 2.42 %
# Number of occurence of  vienna  in test set = 13.77 %
# Number of occurence of  vilnius  in test set = 4.29 %

# %%
languages = np.unique(df['language'])
for language in languages:
    print('Number of occurence of ', language,' in test set = ' "{:.2f}".format(len(df[df['language'] == language].index)/len(df.index)*100), "%")

percent_lan_df = ["{:.2f}".format(len(df[df['language'] == language].index)/len(df.index)*100) for language in languages]
lan = np.array([len(df[df['language'] == i].index) for i in languages])
plt.pie(lan, labels = languages, startangle = 90)
plt.show()
# Out:
# Number of occurence of  austrian  in test set = 4.89 %
# Number of occurence of  belgian  in test set = 2.92 %
# Number of occurence of  bulgarian  in test set = 3.19 %
# Number of occurence of  croatian  in test set = 0.24 %
# Number of occurence of  cypriot  in test set = 6.24 %
# Number of occurence of  czech  in test set = 4.05 %
# Number of occurence of  danish  in test set = 2.74 %
# Number of occurence of  dutch  in test set = 3.80 %
# Number of occurence of  estonian  in test set = 4.30 %
# Number of occurence of  finnish  in test set = 5.67 %
# Number of occurence of  french  in test set = 4.29 %
# Number of occurence of  german  in test set = 3.11 %
# Number of occurence of  greek  in test set = 4.20 %
# Number of occurence of  hungarian  in test set = 3.11 %
# Number of occurence of  irish  in test set = 6.01 %
# Number of occurence of  italian  in test set = 4.83 %
# Number of occurence of  latvian  in test set = 1.04 %
# Number of occurence of  lithuanian  in test set = 3.36 %
# Number of occurence of  luxembourgish  in test set = 5.80 %
# Number of occurence of  maltese  in test set = 3.08 %
# Number of occurence of  polish  in test set = 4.99 %
# Number of occurence of  portuguese  in test set = 1.74 %
# Number of occurence of  romanian  in test set = 2.62 %
# Number of occurence of  slovakian  in test set = 4.34 %
# Number of occurence of  slovene  in test set = 0.43 %
# Number of occurence of  spanish  in test set = 3.95 %
# Number of occurence of  swedish  in test set = 5.05 %

# %%
mobiles = np.unique(df['mobile'])
for mobile in mobiles:
    print('Number of occurence of ', mobile,' in test set = ', len(df[df['mobile'] == mobile].index))

mob = np.array([len(df[df['mobile'] == i].index) for i in mobiles])
plt.pie(mob, labels = mobiles, startangle = 90)
plt.show()
# Out:
# Number of occurence of  0  in test set =  204942
# Number of occurence of  1  in test set =  183035

# %%
sns.distplot(df['date'],kde=True).set(title="Date",xlabel=None)
plt.show()
# Out:
# d:\Logiciels\Anaconda\Installation\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Comparaison des jeux de données

# %%
print("Etude de la variable city:")
df_city = pd.DataFrame()
df_city['city'] = cities
df_city['df_test'] = percent_city_df_test
df_city['df'] = percent_city_df
df_city
# Out:
# Etude de la variable city:
#          city df_test     df
# 0   amsterdam   17.07  17.42
# 1  copenhagen   10.88   7.12
# 2      madrid   16.47  13.51
# 3       paris   16.93  19.63
# 4        rome   10.85  15.36
# 5       sofia    5.63   6.49
# 6    valletta    4.46   2.42
# 7      vienna    8.55  13.77
# 8     vilnius    9.17   4.29

# %%
print("Etude de la variable language:")
df_lan = pd.DataFrame()
df_lan['langues'] = languages
df_lan['df_test'] = percent_lan_df_test
df_lan['df'] = percent_lan_df
df_lan
# Out:
# Etude de la variable language:
#           langues df_test    df
# 0        austrian    6.94  4.89
# 1         belgian    2.30  2.92
# 2       bulgarian    5.36  3.19
# 3        croatian    1.52  0.24
# 4         cypriot    1.60  6.24
# 5           czech    1.57  4.05
# 6          danish    5.21  2.74
# 7           dutch    2.02  3.80
# 8        estonian    5.87  4.30
# 9         finnish    7.01  5.67
# 10         french    1.93  4.29
# 11         german    1.20  3.11
# 12          greek    2.72  4.20
# 13      hungarian   14.55  3.11
# 14          irish    3.15  6.01
# 15        italian    1.93  4.83
# 16        latvian    1.70  1.04
# 17     lithuanian    1.84  3.36
# 18  luxembourgish    1.88  5.80
# 19        maltese    2.97  3.08
# 20         polish    1.97  4.99
# 21     portuguese    1.05  1.74
# 22       romanian    6.61  2.62
# 23      slovakian    6.29  4.34
# 24        slovene    2.62  0.43
# 25        spanish    2.12  3.95
# 26        swedish    6.08  5.05

# %%
sns.distplot(df['date'],kde=True).set(title="Date",xlabel=None)
plt.show()
sns.distplot(df_test['date'],kde=True).set(title="Date",xlabel=None)
plt.show()
# Out:
# d:\Logiciels\Anaconda\Installation\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# d:\Logiciels\Anaconda\Installation\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
